# %%
import pandas as pd 
import numpy as n
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d = pd.read_csv('A.csv')
d.head()
# Out:
#    Gender  Hemoglobin   MCH  MCHC   MCV  Result
# 0       1        14.9  22.7  29.1  83.7       0
# 1       0        15.9  25.4  28.3  72.0       0
# 2       0         9.0  21.5  29.6  71.2       1
# 3       0        14.9  16.0  31.4  87.5       0
# 4       1        14.7  22.0  28.2  99.5       0

# %%
d.columns
# Out:
# Index(['Gender', 'Hemoglobin', 'MCH', 'MCHC', 'MCV', 'Result'], dtype='object')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(d['Gender'],color='red')

plt.subplot(1,2,2)
plt.hist(d['Hemoglobin'],color='blue')
# Out:
# (array([  3.,   3.,   8., 109., 242., 214., 262., 184., 178., 218.]),
#  array([ 6.6 ,  7.63,  8.66,  9.69, 10.72, 11.75, 12.78, 13.81, 14.84,
#         15.87, 16.9 ]),
#  <BarContainer object of 10 artists>)

# %%
d.hist(figsize=(15,55),layout=(15,4), color='red')
plt.show()

# %%
d['MCH'].hist(figsize=(10,5),color='red')
# Out:
# <AxesSubplot:>

# %%
plt.bar(d['MCHC'],d['MCV'], color='red') # scatter, plot, triplot, stackplot
# Out:
# <BarContainer object of 1421 artists>

# %%
plt.boxplot(d['Hemoglobin'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22982689a00>,
#   <matplotlib.lines.Line2D at 0x22982689cd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x22982689fa0>,
#   <matplotlib.lines.Line2D at 0x229826a32b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x22982689730>],
#  'medians': [<matplotlib.lines.Line2D at 0x229826a3580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x229826a3850>],
#  'means': []}

# %%
d['MCH'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.displot(d['MCHC'], color='red') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
sns.residplot(d['MCV'],d['Hemoglobin'], color='red') # residplot, scatterplot
# Out:
# C:\Users\SPIRO15\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MCV', ylabel='Hemoglobin'>

# %%
sns.pairplot(d)

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(d.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <AxesSubplot:>

# %%
def plot(d, variable):
    dataframe_pie = d[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return n.round(dataframe_pie/d.shape[0]*100,2)

plot(d, 'Gender')
# Out:
# 1    52.08
# 0    47.92
# Name: Gender, dtype: float64
